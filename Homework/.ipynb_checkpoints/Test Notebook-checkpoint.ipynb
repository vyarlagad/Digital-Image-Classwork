# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import os

# %%
img = cv2.imread("/Users/Vasukesh/Desktop/pupper.jpg",1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
